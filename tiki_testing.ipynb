# %%
import pandas as pd

# %%
drinks = pd.read_csv('Smugglers Cove - Sheet1.csv')

# %%
drinks.head()
# Out:
#                    Drink  Page                 Glass  Lemon Juice (oz)  \
# 0                Aku Aku    39         chilled coupe               NaN
# 1                 Pupule    39        footed pilsner               NaN
# 2         Don's Own Grog    40  double old-fashioned               NaN
# 3         Port Au Prince    40        footed pilsner               NaN
# 4  Three Dots and a Dash    43        footed pilsner               NaN
#
#    Lime Juice (oz)  Pineapple Juice (oz)  Grapefruit Juice (oz)  \
# 0             1.00                   NaN                    NaN
# 1             0.75                   NaN                    NaN
# 2             0.75                   NaN                    NaN
# 3             0.50                   0.5                    NaN
# 4             0.50                   NaN                    NaN
#
#    Orange Juice (oz)  Ginger Beer (oz)  Bundeberg guava soda (oz)  ...  \
# 0                NaN               NaN                        NaN  ...
# ...

# %%
drinks.columns[20:]
# Out:
# Index(['Honey Syrup (oz)', 'Molasses Syrup (oz)', 'SC Jerk Syrup',
#        'Li Hing Mui Syrup', 'Mai Tai Rich Simple Syrup (oz)',
#        'Martinique sugarcane syrup (oz)', 'Sweet Cream (oz)',
#        'Small Hand Foods Raspberry Gum Syrup (oz)', 'Orgeat (oz)',
#        'Coconut Cream (oz)', 'Pasion fruit puree (oz)', 'Maple Syrup (oz)',
#        'Vanilla Extract (drops)', 'Almond Extract (drops)',
#        'Spruce beet soda extract (drops)', 'Blended Light Aged Rum (oz)',
#        'Sill Aged Rum (oz)', 'Blended Aged Rum (oz)',
#        'Black Blended Rum - Overproof (oz)', 'Black Blended Rum (oz)',
#        'Cane coffey still aged rum (oz)',
#        'Cane AOC Martinique Rhum Agricole Vieux (oz)',
#        'Cane AOC Martinique Rhum Agricole Blanc (oz)',
#        'Column still aged rum (oz)', 'Pot still unaged rum',
#        'Pot still lightly aged rum',
#        'Pot still lightly aged rum - overproof (oz)',
# ...

# %%
rum_drinks = drinks[(drinks['London dry gin (oz)'] > 0) & (drinks['Blended Light Aged Rum (oz)'] > 0) ]

# %%
for idx, row in rum_drinks.iterrows():
    print(rum_drinks.loc[idx][rum_drinks.loc[idx].notna() == True])
# Out:
# Drink                                          Captain's Grog
# Page                                                       65
# Glass                                    double old-fashioned
# Lime Juice (oz)                                           0.5
# Grapefruit Juice (oz)                                     0.5
# Seltzer (oz)                                                1
# Maple Syrup (oz)                                          0.5
# Vanilla Extract (drops)                                     3
# Almond Extract (drops)                                      3
# Blended Light Aged Rum (oz)                              0.75
# Blended Aged Rum (oz)                                    0.75
# Black Blended Rum (oz)                                   0.75
# John D. Taylor's Velvet Falernum (oz)                     0.5
# Pierre Ferrand Dry Curacao (oz)                           0.5
# Name: 12, dtype: object
# Drink                           Peachtree Punch 2.0
# ...

# %%
#getting clean recipe 
for idx, row in rum_drinks.iterrows():
    print(rum_drinks.loc[idx][rum_drinks.loc[idx].notna() == True])
# Out:
# Drink                                                            Don's Own Grog
# Page                                                                         40
# Glass                                                      double old-fashioned
# Lime Juice (oz)                                                            0.75
# Dem Simple Syrup (oz)                                                      0.25
# Blended Aged Rum (oz)                                                       0.5
# Black Blended Rum (oz)                                                      0.5
# Leopold Brothers Rocky Mountain Blackberry Liqueur (oz)                     0.5
# John D. Taylor's Velvet Falernum (oz)                                       0.5
# Angostura Bitters (dash)                                                      1
# Grendine (dash)                                                               1
# Name: 2, dtype: object
# Drink                                   Demerara Dry Float
# ...

# %%
class Tiki_Bar():
    # instantiate with ingredients in bar
    # call function to show recipes you can make
    # call function to return recipe missing one ingredient

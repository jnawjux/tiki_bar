# %%
from tiki_bar import Tiki_Bar

# %%
my_bar = Tiki_Bar()

# %%
my_bar.recipe_by_ingredient('Orange Juice')
# Out:
# Recipes with the ingredient:
# Pupule
# ------
# Lime Juice (oz): 0.75
# Orange Juice (oz): 0.75
# Cinnamon Syrup (oz): 0.25
# Vanilla Syrup (oz): 0.25
# Sill Aged Rum (oz): 2.0
# St. Elizabeth Allspice Dram (oz): 0.25
# Angostura Bitters (dash): 1.0
# Spiral Cut Orange Peel (q): 1.0
# Glass: footed pilsner
# ------
#
# Three Dots and a Dash
# ------
# Lime Juice (oz): 0.5
# Orange Juice (oz): 0.5
# Honey Syrup (oz): 0.5
# Blended Aged Rum (oz): 0.5
# Cane AOC Martinique Rhum Agricole Vieux (oz): 1.5
# St. Elizabeth Allspice Dram (oz): 0.25
# John D. Taylor's Velvet Falernum (oz): 0.25
# Angostura Bitters (dash): 1.0
# Glass: footed pilsner
# ------
#
# Halekulani Cocktail
# ------
# Lemon Juice (oz): 0.5
# Pineapple Juice (oz): 0.5
# Orange Juice (oz): 0.5
# Dem Simple Syrup (oz): 0.25
# Bourbon (oz): 1.5
# Angostura Bitters (dash): 1.0
# Grendine (dash): 2.0
# Glass: chilled coupe
# ------
#
# Sidewinder's Fang
# ------
# Lime Juice (oz): 1.5
# Orange Juice (oz): 1.5
# ...

# %%
my_bar.on_hand = ['Lime Juice', 'Cinnamon Syrup', 'Dem Simple Syrup']

my_bar.what_can_i_make(exact=1)
# Out:
# Can make:
# Grog
# ------
# Lime Juice (oz): 0.5
# Dem Simple Syrup (oz): 0.5
# Blended Aged Rum (oz): 2.0
# Glass: double old-fashioned
# ------
#
# Bombo
# ------
# Dem Simple Syrup (oz): 0.25
# Blended Aged Rum (oz): 2.0
# Glass: double old-fashioned
# ------
#
# Daiquiri No. 1
# ------
# Lime Juice (oz): 0.75
# Dem Simple Syrup (oz): 0.5
# Blended Light Aged Rum (oz): 2.0
# Glass: chilled coupe
# ------

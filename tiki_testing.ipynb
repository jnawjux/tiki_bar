# %%
from tiki_bar import Tiki_Bar

# %%
my_bar = Tiki_Bar('all_drinks.csv')

# %%
my_bar.recipe_by_ingredient('Orange Juice')
# Out:
# Recipes with the ingredient:
# Pupule
# ------
# Lime Juice (oz): 0.75
# Orange Juice (oz): 0.75
# Cinnamon Syrup (oz): 0.25
# Vanilla Syrup (oz): 0.25
# Sill Aged Rum (oz): 2.0
# St. Elizabeth Allspice Dram (oz): 0.25
# Angostura Bitters (dash): 1.0
# Spiral Cut Orange Peel (q): 1.0
# Glass: footed pilsner
# ------
#
# Three Dots and a Dash
# ------
# Lime Juice (oz): 0.5
# Orange Juice (oz): 0.5
# Honey Syrup (oz): 0.5
# Blended Aged Rum (oz): 0.5
# Cane AOC Martinique Rhum Agricole Vieux (oz): 1.5
# St. Elizabeth Allspice Dram (oz): 0.25
# John D. Taylor's Velvet Falernum (oz): 0.25
# Angostura Bitters (dash): 1.0
# Glass: footed pilsner
# ------
#
# Halekulani Cocktail
# ------
# Lemon Juice (oz): 0.5
# Pineapple Juice (oz): 0.5
# Orange Juice (oz): 0.5
# Dem Simple Syrup (oz): 0.25
# Bourbon (oz): 1.5
# Angostura Bitters (dash): 1.0
# Grendine (dash): 2.0
# Glass: chilled coupe
# ------
#
# Sidewinder's Fang
# ------
# Lime Juice (oz): 1.5
# Orange Juice (oz): 1.5
# ...

# %%
my_bar.on_hand = ['Lime Juice', 'Cinnamon Syrup', 'Dem Simple Syrup', 'Pineapple Juice', 'Lemon Juice', 'Angostura Bitters']

my_bar.what_can_i_make(exact=2)
# Out:
# [{'name': 'Port Au Prince',
#   'ingredients': 'Lime Juice (oz): 0.5\nPineapple Juice (oz): 0.5\nDem Simple Syrup (oz): 0.25\nCane coffey still aged rum (oz): 1.5\nAngostura Bitters (dash): 1.0\nGrendine (dash): 1.0\nGlass: footed pilsner'},
#  {'name': 'Hurricane',
#   'ingredients': 'Lemon Juice (oz): 2.0\nPassion Fruit Syrup: 2.0\nBlack Blended Rum (oz): 4.0\nGlass: hurricane glass'},
#  {'name': 'Mundo Perdido',
#   'ingredients': 'Lemon Juice (oz): 0.75\nDem Simple Syrup (oz): 0.25\nCinnamon Syrup (oz): 0.25\nBlack Blended Rum (oz): 1.5\nApple brandy (oz): 0.5\nGlass: chilled coupe'},
#  {'name': 'Jungle Bird',
#   'ingredients': 'Lime Juice (oz): 0.5\nPineapple Juice (oz): 2.0\nDem Simple Syrup (oz): 0.5\nBlack Blended Rum (oz): 1.5\nCampari (oz): 0.75\nGlass: collins or highball'},
#  {'name': 'Chartreuse Swizzle',
# ...
